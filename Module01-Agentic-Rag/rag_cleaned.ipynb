# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
openai_client  = OpenAI()

# %%
documents = load_faq_data()
index = build_index(documents)

# %%
assistant = RAGBase(index, openai_client)

# %%
assistant.rag("I just found out about the course, can I still join?")
# Out:
# 'Yes, you can still join. If you want a certificate, you need to submit your project while submissions are still being accepted.'

# %%
answer = assistant.rag("How can i get a certificate for the course?")
print(answer)
# Out:
# To get a certificate, you need to:
#
# - finish the course with a **live cohort**
# - complete the **capstone project**
# - complete the **required peer reviews**
#
# Homework is **not required** for the certificate.
#
# You can study in self-paced mode and prepare your project, but **project submission and peer review must happen while a live cohort is accepting them**.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# To get a certificate, you need to:
#
# - finish the course with a **live cohort**
# - complete the **capstone project**
# - complete the **required peer reviews**
#
# Homework is **not required** for the certificate.
#
# You can study in self-paced mode and prepare your project, but **project submission and peer review must happen while a live cohort is accepting them**.
